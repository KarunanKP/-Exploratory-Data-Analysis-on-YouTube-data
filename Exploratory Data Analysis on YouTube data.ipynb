# %%
import pandas as pd

# %%
df = pd.read_csv('youtube_dislike_dataset.csv')
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %%
df1=df.copy()

# %% [markdown]
# # Questions:-
# ### 1. Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top 5 and bottom 5 records.

# %%
df.head(5)
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
df.tail(5)
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %% [markdown]
# ### 2. Check the info of the dataframe and write your inferences on data types and shape of the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %%
df.shape
# Out:
# (37422, 12)

# %% [markdown]
# Based on the provided information from the DataFrame:
#
# -The DataFrame has a total of 37,422 entries (rows) and 12 columns.
#
# -The dataset contains a mixture of data types: integer (int64) and object (string).
#
#
# Here are the inferences about the data types and shape of the dataset:
# #### Data Types:
#
# There are 4 columns with integer (numeric) data types: view_count, likes, dislikes, and comment_count.
#
# There are 8 columns with object data types:
# video_id, title, channel_id, channel_title, published_at: These columns likely contain text or identifier information.
#
# tags, description, comments: These columns likely contain text data (tags, video descriptions, and comments).
# #### Shape of the Dataset:
#
# The dataset has 37,422 rows (entries) and 12 columns.
#
# Each row represents a specific video or piece of content, while the columns represent various attributes or characteristics of the videos.
# #### Missing Values:
#
# The comments column has missing values (null or NaN) in some rows.
#
# The non-null count for this column is 37,264, which is slightly less than the total number of entries (37,422).
#
# This indicates that there are missing comments in some rows.

# %% [markdown]
# ### 3. Check for the Percentage of the missing values and drop or impute them.

# %%
missing_percentage = (df.isna().sum() / len(df)) * 100
print(missing_percentage)
# Out:
# video_id         0.000000
# title            0.000000
# channel_id       0.000000
# channel_title    0.000000
# published_at     0.000000
# view_count       0.000000
# likes            0.000000
# dislikes         0.000000
# comment_count    0.000000
# tags             0.000000
# description      0.000000
# comments         0.422212
# dtype: float64

# %% [markdown]
# ### ANS:
# As the comment contains catgorical unique values so you cannot impute them so droping it is a better idea

# %%
df=df.drop(columns =['comments'])
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %% [markdown]
# ## 4. Check the statistical summary of both numerical and categorical columns and write your inferences.

# %%
numerical_summary = df.describe(include=['int64'])
numerical_summary
# Out:
#          view_count         likes      dislikes  comment_count
# count  3.742200e+04  3.742200e+04  3.742200e+04   3.742200e+04
# mean   5.697838e+06  1.668147e+05  4.989862e+03   9.924930e+03
# std    2.426622e+07  5.375670e+05  3.070824e+04   1.171003e+05
# min    2.036800e+04  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    5.122970e+05  1.323350e+04  2.810000e+02   9.000000e+02
# 50%    1.319078e+06  4.233050e+04  7.960000e+02   2.328000e+03
# 75%    3.670231e+06  1.304698e+05  2.461750e+03   6.184000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07

# %%
categorical_summary = df.describe(include=['object'])
categorical_summary
# Out:
#            video_id  title                channel_id        channel_title  \
# count         37422  37422                     37422                37422
# unique        37422  37113                     10961                10883
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
#
#                published_at   tags description
# count                 37422  37422       37422
# unique                36772  28799       35630
# top     2020-10-16 04:00:10
# freq                      6   3817         589

# %% [markdown]
# ## Inferences:
#
# The data seems to represent videos on some platform, with information about view counts, likes, dislikes, comment counts, and various attributes related to the videos.
#
# The numerical columns (view counts, likes, dislikes, and comment counts) show a wide range of values with significant variability.
#
# The categorical columns have various unique values, suggesting diversity in video titles, channel IDs, and other categorical attributes.
#
# The high frequency of the published date "2020-10-16 04:00:10" might also indicate some specific event or trend related to video publishing.

# %% [markdown]
# ## 5. Convert datatype of column published_at from object to pandas datetime

# %%
df['published_at'] = pd.to_datetime(df['published_at'])

# %%
df.dtypes
# Out:
# video_id                 object
# title                    object
# channel_id               object
# channel_title            object
# published_at     datetime64[ns]
# view_count                int64
# likes                     int64
# dislikes                  int64
# comment_count             int64
# tags                     object
# description              object
# dtype: object

# %% [markdown]
# ## 6. Create a new column as 'published_month' using the column published_at (display the months only)

# %%
df['published_month'] = df['published_at'].dt.month

# %%
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %% [markdown]
# ## 7. Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb' and so on.....

# %%
months = {1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'Jun',7:'July',8:'Aug',9:'Sep',10:'Oct',11:'Nov',12:'Dec'}
df['published_month'] = df['published_at'].dt.month.map(months)

# %%
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %% [markdown]
# ## 8. Find the number of videos published each month and arrange the months in a decreasing order based on the video count.

# %%
video_count_by_month = df.groupby('published_month').size()
sorted_video_count = video_count_by_month.sort_values(ascending=False)
print(sorted_video_count)
# Out:
# published_month
# Oct     4991
# Sep     4880
# Nov     4851
# Aug     4262
# Dec     3072
# July    2340
# Jun     2316
# Mar     2258
# Feb     2137
# Apr     2126
# Jan     2108
# May     2081
# dtype: int64

# %% [markdown]
# ## 9. Find the count of unique video_id, channel_id and channel_title.

# %%
unique_video_id_count = df['video_id'].nunique()
unique_channel_id_count = df['channel_id'].nunique()
unique_channel_title_count = df['channel_title'].nunique()

print("Unique Video IDs:", unique_video_id_count)
print("Unique Channel IDs:", unique_channel_id_count)
print("Unique Channel Titles:", unique_channel_title_count)
# Out:
# Unique Video IDs: 37422
# Unique Channel IDs: 10961
# Unique Channel Titles: 10883

# %% [markdown]
# ## 10. Find the top10 channel names having the highest number of videos in the dataset and the bottom10 having lowest number of videos.

# %%
channel_video_counts = df['video_id'].groupby(df['channel_title']).count()
top_10_channels = channel_video_counts.sort_values(ascending=False).head(10)
bottom_10_channels = channel_video_counts.sort_values(ascending=True).head(10)

print("Top 10 Channels with Highest Videos:")
print(top_10_channels)

print("\nBottom 10 Channels with Lowest Videos:")
print(bottom_10_channels)
# Out:
# Top 10 Channels with Highest Videos:
# channel_title
# Sky Sports Football    533
# The United Stand       301
# BT Sport               246
# NBA                    209
# NFL                    162
# WWE                    122
# SSSniperWolf            99
# SSundee                 98
# FORMULA 1               87
# NHL                     86
# Name: video_id, dtype: int64
#
# Bottom 10 Channels with Lowest Videos:
# channel_title
#    SilverName                   1
# Mini Muka                       1
# Mini Ladd                       1
# MindYourLogic                   1
# Mind Body Tonic With Dr Sita    1
# Mimi Ar                         1
# Millyz                          1
# Milkair                         1
# Milissa Grande                  1
# MikuruSong                      1
# Name: video_id, dtype: int64

# %% [markdown]
# ## 11. Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences.

# %%
max_likes_title = df.loc[df['likes'].idxmax()]['title']
min_likes_title = df.loc[df['likes'].idxmin()]['title']

print("Video with Maximum Likes:", max_likes_title)
print("Video with Minimum Likes:", min_likes_title)
# Out:
# Video with Maximum Likes: BTS () 'Dynamite' Official MV
# Video with Minimum Likes: Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News

# %% [markdown]
# ## Inference :
# we can gather that "BTS 'Dynamite' Official MV" has received the highest number of likes among the videos in the dataset, while a video featuring Kim Kardashian's moments on "Saturday Night Live" has the lowest number of likes.

# %% [markdown]
# ## 12. Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your inferences.

# %%
max_dislikes_title = df.loc[df['dislikes'].idxmax()]['title']
min_dislikes_title = df.loc[df['dislikes'].idxmin()]['title']

print("Video with Maximum Dislikes:", max_dislikes_title)
print("Video with Minimum Dislikes:", min_dislikes_title)
# Out:
# Video with Maximum Dislikes: Cuties | Official Trailer | Netflix
# Video with Minimum Dislikes: Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News

# %% [markdown]
# ## Inference :
# we can gather that the "Cuties" trailer faced a notable level of disapproval from the audience, possibly due to controversies or differing opinions about its content. On the other hand, the Kim Kardashian-related video seems to have generated less negativity in terms of dislikes.

# %% [markdown]
# ## 13. Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

correlation = df['view_count'].corr(df['dislikes'])

plt.figure(figsize=(10, 6))
sns.scatterplot(x='view_count', y='dislikes', data=df)
plt.title(f'Correlation: {correlation:.2f}')
plt.xlabel('Number of Views')
plt.ylabel('Number of Dislikes')
plt.show()

print("Correlation between views and dislikes:", correlation)
# Out:
# Correlation between views and dislikes: 0.6844687753905547

# %% [markdown]
# ## 14. Display all the information about the videos that were published in January, and mention the count of videos that were published in January.

# %%
videos_in_january = df[df['published_month'] == 'Jan']
print("Videos Published in January:")
print(videos_in_january)

count_january_videos = videos_in_january.shape[0]
print("Count of Videos Published in January:", count_january_videos)
# Out:
# Videos Published in January:
#           video_id                                              title  \
# 27     -2Gwm7QfBnE                                    Q&A With Naisha
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title        published_at  \
# ...
